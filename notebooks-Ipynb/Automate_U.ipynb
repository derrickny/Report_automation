# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/nyagaderrick/Developer/Report_automation/January 2024 Attendance-USIU.xlsx")

# %%
df.head()
# Out:
#             Name      Date Clock In Clock Out
# 0  Jackline Oira  1/1/2024      NaN       NaN
# 1  Jackline Oira  1/2/2024    07:55       NaN
# 2  Jackline Oira  1/3/2024    07:49     18:00
# 3  Jackline Oira  1/4/2024    07:41     17:59
# 4  Jackline Oira  1/5/2024    11:25     17:57

# %%
#convert date column from this format 1/1/2024 to this format dd/mm/yyyy
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%d/%m/%Y')

# %%
df.head(50)
# Out:
#               Name        Date Clock In Clock Out
# 0    Jackline Oira  01/01/2024      NaN       NaN
# 1    Jackline Oira  02/01/2024    07:55       NaN
# 2    Jackline Oira  03/01/2024    07:49     18:00
# 3    Jackline Oira  04/01/2024    07:41     17:59
# 4    Jackline Oira  05/01/2024    11:25     17:57
# 5    Jackline Oira  06/01/2024    08:18     13:22
# 6    Jackline Oira  08/01/2024    07:43     18:08
# 7    Jackline Oira  09/01/2024    07:45     18:11
# 8    Jackline Oira  10/01/2024    07:51     18:02
# 9    Jackline Oira  11/01/2024    07:42     17:56
# 10   Jackline Oira  12/01/2024    07:49     17:53
# 11   Jackline Oira  13/01/2024    07:41     13:06
# 12   Jackline Oira  15/01/2024    07:31     18:05
# 13   Jackline Oira  16/01/2024    07:38     18:01
# 14   Jackline Oira  17/01/2024    07:30     17:38
# 15   Jackline Oira  18/01/2024    07:20     18:10
# 16   Jackline Oira  19/01/2024    07:33     17:58
# 17   Jackline Oira  20/01/2024      NaN       NaN
# ...

# %%
#save that to the excel sheet 
df.to_excel("/Users/nyagaderrick/Developer/Report_automation/January 2024 Attendance-USIU.xlsx", index=False)
